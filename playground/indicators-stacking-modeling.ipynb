# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from datetime import datetime, timedelta
from jellyfish.candles_loader import load_candles_history
from jellyfish.core import Client

end_dt = datetime(year=2020, month=11, day=3)
start_dt = end_dt - timedelta(days=30 * 12 * 3)
original_frame = load_candles_history(Client(), 'BTCUSDT', start_dt, end_dt, '15m')
original_frame.head()
# Out:
#   0%|          | 0/104 [00:00<?, ?it/s]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#   1%|          | 1/104 [00:00<01:36,  1.07it/s]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#   2%|▏         | 2/104 [00:01<01:40,  1.02it/s]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#   3%|▎         | 3/104 [00:06<04:03,  2.41s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#   4%|▍         | 4/104 [00:08<04:19,  2.59s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#   5%|▍         | 5/104 [00:10<03:52,  2.35s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#   6%|▌         | 6/104 [00:11<03:03,  1.87s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#   7%|▋         | 7/104 [00:12<02:36,  1.62s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#   8%|▊         | 8/104 [00:13<02:14,  1.40s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#   9%|▊         | 9/104 [00:15<02:08,  1.35s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  10%|▉         | 10/104 [00:16<02:05,  1.34s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  11%|█         | 11/104 [00:17<01:55,  1.24s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  12%|█▏        | 12/104 [00:19<02:13,  1.45s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  12%|█▎        | 13/104 [00:22<02:48,  1.85s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  13%|█▎        | 14/104 [00:24<03:07,  2.09s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  14%|█▍        | 15/104 [00:27<03:13,  2.18s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  15%|█▌        | 16/104 [00:28<02:38,  1.80s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  16%|█▋        | 17/104 [00:29<02:20,  1.62s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  17%|█▋        | 18/104 [00:30<02:20,  1.64s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  18%|█▊        | 19/104 [00:31<02:01,  1.42s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  19%|█▉        | 20/104 [00:33<01:56,  1.39s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  20%|██        | 21/104 [00:34<01:51,  1.34s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  21%|██        | 22/104 [00:35<01:40,  1.23s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  22%|██▏       | 23/104 [00:36<01:33,  1.16s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  23%|██▎       | 24/104 [00:37<01:36,  1.20s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  24%|██▍       | 25/104 [00:38<01:28,  1.13s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  25%|██▌       | 26/104 [00:39<01:26,  1.11s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  26%|██▌       | 27/104 [00:40<01:27,  1.13s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  27%|██▋       | 28/104 [00:41<01:21,  1.07s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  28%|██▊       | 29/104 [00:43<01:23,  1.12s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  29%|██▉       | 30/104 [00:44<01:23,  1.12s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  30%|██▉       | 31/104 [00:45<01:19,  1.10s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  31%|███       | 32/104 [00:46<01:23,  1.16s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  32%|███▏      | 33/104 [00:47<01:17,  1.10s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  33%|███▎      | 34/104 [00:48<01:21,  1.17s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  34%|███▎      | 35/104 [00:49<01:15,  1.09s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  35%|███▍      | 36/104 [00:50<01:18,  1.16s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  36%|███▌      | 37/104 [00:51<01:13,  1.09s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  37%|███▋      | 38/104 [00:52<01:10,  1.07s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  38%|███▊      | 39/104 [00:54<01:14,  1.15s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  38%|███▊      | 40/104 [00:55<01:11,  1.11s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  39%|███▉      | 41/104 [00:56<01:18,  1.24s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  40%|████      | 42/104 [00:58<01:32,  1.48s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  41%|████▏     | 43/104 [01:00<01:27,  1.44s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  42%|████▏     | 44/104 [01:01<01:28,  1.47s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  43%|████▎     | 45/104 [01:03<01:26,  1.46s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  44%|████▍     | 46/104 [01:04<01:22,  1.41s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  45%|████▌     | 47/104 [01:05<01:13,  1.30s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#
/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  96%|█████████▌| 100/104 [02:12<00:04,  1.09s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  97%|█████████▋| 101/104 [02:14<00:03,  1.14s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  98%|█████████▊| 102/104 [02:15<00:02,  1.18s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
#  99%|█████████▉| 103/104 [02:18<00:01,  1.62s/it]/home/tarasnovokhatskiy/jellyfish/.venv/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)
# 100%|██████████| 104/104 [02:19<00:00,  1.34s/it]
#                        Close     High      Low  NumOfTrades     Open  \
# Date
# 2017-11-19 02:14:00  7769.03  7773.90  7750.66         97.0  7761.94
# 2017-11-19 02:29:00  7760.51  7777.34  7750.66        138.0  7769.02
# 2017-11-19 02:44:00  7783.48  7783.74  7760.01        153.0  7777.33
# 2017-11-19 02:59:00  7772.00  7783.43  7770.01        186.0  7772.47
# 2017-11-19 03:14:00  7777.56  7777.56  7760.01         86.0  7772.01
#
#                      QuoteAssetVolume  TakerBuyAssetVolume  \
# Date
# 2017-11-19 02:14:00     101391.917694             7.037228
# 2017-11-19 02:29:00     414469.711910            23.377750
# 2017-11-19 02:44:00     159157.215891            10.281019
# 2017-11-19 02:59:00     200510.701352             6.642740
# 2017-11-19 03:14:00      76295.857197             4.357808
#
#                      TakerSellAssetVolume     Volume
# Date
# 2017-11-19 02:14:00          54674.070249  13.052261
# 2017-11-19 02:29:00         181763.014334  53.328862
# 2017-11-19 02:44:00          79912.468142  20.480561
# 2017-11-19 02:59:00          51657.261217  25.794508
# 2017-11-19 03:14:00          33853.152869   9.824223

# %%
from jellyfish import indicator, utils
from jellyfish.transform import sampling

frame = original_frame.copy()
frame = sampling.tick_imbalance(frame.reset_index(), 20)

# for days in [1, 5, 10, 50]:
#     frame[f'i_sma_{days}'] = indicator.sma(frame.Close.to_numpy(), days)
#     frame[f'i_ema_{days}'] = indicator.ema(frame.Close.to_numpy(), days)

for period in [10, 15, 35]:
    frame[f'i_aroon_{period}'] = indicator.aroon_oscillator(frame.Low.to_numpy(), frame.High.to_numpy(), period=period)

for period in [4, 7, 10, 15]:
    frame[f'i_rsi_{period}'] = indicator.rsi(frame.Close.to_numpy(), period)

frame['i_hurst_random'] = indicator.hurst(frame.Close.to_numpy())
frame['i_hurst_change'] = indicator.hurst(frame.Close.to_numpy(), kind=indicator.HURST_CHANGE)
# frame['i_volume'] = frame.Volume

# upper, lower = indicator.bollinger_bands(frame, 10, 1.5)
# frame['i_bband_low'] = lower
# frame['i_bband_high'] = upper

for c in frame.columns:
    if c.startswith('i_'):
        frame[c] = (frame[c] - frame[c].mean()) / frame[c].std()

frame.dropna(inplace=True)
# utils.plot_ohlc(frame)
len(frame)
# Out:
# 100%|██████████| 103342/103342 [00:39<00:00, 2646.37it/s]
# 5068

# %%
import pandas as pd
import numpy as np

def get_X(frame: pd.DataFrame):
    return frame.filter(like='i_').values

def get_y(frame: pd.DataFrame, th=3e-2):
    y = frame.Close.pct_change(20).shift(-20)
    y[y.between(-th, th)] = 0
    y[y > 0] = 1
    y[y < 0] = -1
    return y

def get_feed_data(frame: pd.DataFrame, th=0):
    X = get_X(frame)
    y = get_y(frame, th)

    isnan = np.isnan(y)
    X = X[~isnan]
    y = y[~isnan]

    return X, y

X, y = get_feed_data(frame);
X.shape, y.shape
# Out:
# ((5048, 9), (5048,))

# %%
import matplotlib.pyplot as plt
plt.plot(y)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=0)
clf = KNeighborsClassifier(7)  # Model the output based on 7 "nearest" examples
cf = XGBRegressor()
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

_ = pd.DataFrame({'y_true': y_test, 'y_pred': y_pred}).plot(figsize=(15, 2), alpha=.7)
print('Classification accuracy: ', np.mean(y_test == y_pred))
# Out:
# Classification accuracy:  0.6303630363036303

# %%
from jellyfish.core import Strategy, Backtest


N_TRAIN = len(X_train)


class MLTrainOnceStrategy(Strategy):
    price_delta = .004  # 0.4%

    def init(self):
        # Init our model, a kNN classifier
        self.clf = XGBRegressor()

        # Train the classifier in advance on the first N_TRAIN examples
        df = self.data.df.iloc[:N_TRAIN]
        X, y = get_feed_data(df)
        self.clf.fit(X, y)

        # Plot y for inspection
        self.I(get_y, self.data.df, name='y_true')

        # Prepare empty, all-NaN forecast indicator
        self.forecasts = self.I(lambda: np.repeat(np.nan, len(self.data)), name='forecast')
        self.confidences = self.I(lambda: np.repeat(np.nan, len(self.data)), name='confidence')

    def next(self):
        # Skip the training, in-sample data
        if len(self.data) < N_TRAIN:
            return

        # Proceed only with out-of-sample data. Prepare some variables
        high, low, close = self.data.High, self.data.Low, self.data.Close

        # Forecast the next movement
        X = get_X(self.data.df.iloc[-1:])

        # Update the plotted "forecast" indicator
        confidence = self.clf.predict(X)[0]
        forecast = 1 if confidence > 0 else -1
        self.confidences[-1] = abs(confidence)
        self.forecasts[-1] = forecast

        # If our forecast is upwards and we don't already hold a long position
        # place a long order for 20% of available account equity. Vice versa for short.
        # Also set target take-profit and stop-loss prices to be one price_delta
        # away from the current closing price.
        if forecast == 1 and not self.position.is_long:
            self.buy()
        elif forecast == -1 and not self.position.is_short:
            self.sell()


bt = Backtest(frame, MLTrainOnceStrategy, cash=1e6)
stats = bt.run()
bt.plot()
stats
# Out:
# /tmp/ipykernel_9742/3997151841.py:53: UserWarning: Data index is not datetime. Assuming simple periods, but `pd.DateTimeIndex` is advised.
#   bt = Backtest(frame, MLTrainOnceStrategy, cash=1e6)
# Start                                   100.0
# End                                    5167.0
# Duration                               5067.0
# Exposure Time [%]                   30.288082
# Equity Final [$]                    236949.55
# Equity Peak [$]                    1173721.44
# Return [%]                         -76.305045
# Buy & Hold Return [%]                  -5.328
# Return (Ann.) [%]                         0.0
# Volatility (Ann.) [%]                     NaN
# Sharpe Ratio                        -0.685851
# Sortino Ratio                       -0.463911
# Calmar Ratio                        -0.433706
# Max. Drawdown [%]                  -82.874911
# Avg. Drawdown [%]                   -5.112796
# Max. Drawdown Duration                 1132.0
# Avg. Drawdown Duration              69.090909
# # Trades                                244.0
# Win Rate [%]                        51.639344
# Best Trade [%]                      15.177415
# Worst Trade [%]                    -78.213199
# Avg. Trade [%]                      -0.736354
# Max. Trade Duration                     913.0
# Avg. Trade Duration                  8.872951
# Profit Factor                        0.742856
# Expectancy [%]                       -0.36634
# SQN                                 -1.042205
# _strategy                 MLTrainOnceStrategy
# _equity_curve                       Equity...
# _trades                        Size  Entry...
# dtype: object
